# %%
if(name=="xyz"){
    something;
    something;
}
else{
    something else;
    something else;
}
# Out:
#   Cell In[1], line 1
#     if(name=="xyz"){
#                    ^
# SyntaxError: invalid syntax

# %%
name="244"
if name=="xyz":
print('line1')
    print('lin2')
else:
    
    print('line3')
# Out:
#   Cell In[2], line 3
#     print('line1')
#     ^
# IndentationError: expected an indented block after 'if' statement on line 2

# %%
name="244"
if name=="xyz":
    print('line1')
    print('lin2')
else:
    
    print('line3')
# Out:
# line3
