# %%
#1.Array homogenous list hetrogenous
#2.Array me co
#3. Arrays are much faster
#4. List are more programmer friendly

# %%
L=[]
L = [1,2,3]
L2=["Satyam",4,5.6,True] #hetrogenous list
L3=[1,2,3,[4,5]] #multi-dim lists
#3D
L4=[[[1,2],[3,4]],[[5,6],[7,8]]]
L5=list("Satyam")
print(L5)
L[0]
L[::-1]
L3[0]
L3[-1]
# Out:
# ['S', 'a', 't', 'y', 'a', 'm']
# [4, 5]

# %%
L4=[[[1,2],[3,4]],[[5,6],[7,8]]]
L4[1][1][0]
# Out:
# 7

# %%
#Edit
L = [1,2,3]
L[0]=100
# List in python are Mutable
L
#You also use slicing
# Out:
# [100, 2, 3]

# %%
# Add
#append
#extend
#insert
L=[100, 2, 3]
L.append(1000)

L.extend([600,500])
L.append([5,6])
L.extend("goa")
L.insert(1,"world")
L
# Out:
# [100, 'world', 2, 3, 1000, 600, 500, [5, 6], 'g', 'o', 'a']

# %%
#Delete
#del
#remove
#clear
#pop
L=[100, 'world', 2, 3, 1000, 600, 500, [5, 6], 'g', 'o', 'a']

del L[0]
L.pop()
# Out:
# 'a'

# %%
#Operation on List
L=[1,2,3,4]
L1=[5,6,7,8]
L+L1
L*3
for i in L:
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
#Function
L=[1,2,3,4]
len(L)
min(L)
max(L)
L.sort()
L
L.sort(reverse=True)
L
# Out:
# [4, 3, 2, 1]

# %%
"satyam".title()
# Out:
# 'Satyam'
