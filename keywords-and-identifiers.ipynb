# %%
#Keywords ----> Python is a case sensitive programming language(differnce lower case and upper case)
#---> In a programming, a keyword is a word that is reserved by a program because the word has sepcial meaning. Keywords can  be commands  or pararmeters. Every programming language has a set of keywords  that can not be used as variable name.

# %%
#python has 33 keywords
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
#Identifiers
#--->  A Python identifier is a name used to identify a variable,function, class, module or other object


#Rules for setting identifiers
#-->can only start with an alphapet or_
#--> Followed by 0 or more letter,_ and digits
#-->keywords cannot be used as an identifiers

# %%
name='Satyam'
print(name)
# Out:
# Satyam

# %%
1name='Satyam'
print(1name)
# Out:
#   Cell In[7], line 1
#     1name='Satyam'
#     ^
# SyntaxError: invalid decimal literal

# %%
name1='Satyam'
print(name1)
# Out:
# Satyam

# %%
_='Satyam'
print(_)
# Out:
# Satyam

# %%
False='Satyam'
print(False)
# Out:
#   Cell In[10], line 1
#     False='Satyam'
#     ^
# SyntaxError: cannot assign to False
