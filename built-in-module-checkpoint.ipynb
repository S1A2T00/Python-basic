# %%
#What are module
#--->Consider a module to be the as a code library.

#--->A file containing a set of functions you want to include in your application.

#-->example-
#--->Math
#--->Random
#--->os
#-->time

# %%
import math

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.ceil
# Out:
# <function math.ceil(x, /)>

# %%
math.e
# Out:
# 2.718281828459045

# %%
math.sqrt(100)
# Out:
# 10.0

# %%
import random

# %%
random.randint(1,100)
# Out:
# 64

# %%
a = [1,2,3,4,5]
random.shuffle(a)

# %%
import time

# %%
time.time()
# Out:
# 1763980162.393958

# %%
time.ctime()
# Out:
# 'Mon Nov 24 15:59:35 2025'

# %%
print("Hello")
time.sleep(1)
print("World")
# Out:
# Hello
# World

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Saytam Pandey\\Desktop\\SatyamPython'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'break-continue-and-pass.ipynb',
#  'built-in-function.ipynb',
#  'built-in-module.ipynb',
#  'comments.ipynb',
#  'data-types1.ipynb',
#  'decision-control.ipynb',
#  'for loop.ipynb',
#  'guessing number.ipynb',
#  'indentation.ipynb',
#  'keywords-and-identifiers.ipynb',
#  'literals.ipynb',
#  'loop.ipynb',
#  'nested-loop.ipynb',
#  'Operators.ipynb',
#  'python fun.ipynb',
#  'taking-user-input-and type-conversion.ipynb',
#  'variables_in_python.ipynb']
