# %%
#Tubles 
#Sets
# Dictionary
# Problems

# %%
#Tubles 
#Create
#Access
#Edit
#Add
#Delete
#Operation
#Functions

# %%
#Create
T1=()
T1
# Out:
# ()

# %%
T3=("Hello",4,5,6)
T3
# Out:
# ('Hello', 4, 5, 6)

# %%
#Single item tuple
T4=(4,)
type(T4)
# Out:
# tuple

# %%
T6=tuple([1,2,3,4,5])
T6
# Out:
# (1, 2, 3, 4, 5)

# %%
#Access
T2=(1,2,3,4,5)
T2[0]
#Tuble does not support editing i.e are immutable
#So not any new element in tuple
# Out:
# 1

# %%
#Delete
T2=(1,2,3,4,5)
del T2[-1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 #Delete
#       2 T2=(1,2,3,4,5)
# ----> 3 del T2[-1]
#
# TypeError: 'tuple' object doesn't support item deletion

# %%
#Operation
#-->add two tuple(T1+T2)
#Functions
T2=(1,2,3,4,5)
len(T2)
# Out:
# 5

# %%
#Tuples are read-only data type
