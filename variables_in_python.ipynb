# %%
#C Lang
#int a=5

# %%
name='Satyam'

# %%
print(name)
# Out:
# Satyam

# %%
#no variable declartion in python

# %%
#Dynamic Typing(use in python) --->PHP also
#Static Typing(Use not Python)

# %%
name=4
print(name)
# Out:
# 4

# %%
name=True
print(name)
# Out:
# True

# %%
#not binded data type in python because change user value
#This binding called Dynamic Binding(one variable change it data type) use in python

# %%
#Static Binding
# when delcalre any value like int,float then this will not change(like C lang,Java etc not in python)

# %%
#Special Syntax
a=4;b=6;c=7;
print(a)
print(b)
print(c)
# Out:
# 4
# 6
# 7

# %%
a,b,c=4,5,6
print(a)
print(b)
print(c)
# Out:
# 4
# 5
# 6
