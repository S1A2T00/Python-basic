# %%
#--->Strings are sequence of Characters
#--> In python specifically, strings are a sequence of Unicode Characters
#--->Creating Strings
#--->Adding Chars to Strings
#---> Editing Strings
#--->Accessings Strings
#--->Deleting Strings
#--->Operations on Strings
#----> Strings Functions

# %%
#Creating Strings
c = "Hello"
print(c)
# Out:
# Hello

# %%
'It's raining outside'
# Out:
#   Cell In[2], line 1
#     'It's raining outside'
#                          ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
"It's raining outside"
# Out:
# "It's raining outside"

# %%
c = '''Hello'''
print(c)
#multi line strings
# Out:
# Hello

# %%
c = """Hello"""
print(c)
# Out:
# Hello

# %%
c = str("Hello")
c
# Out:
# 'Hello'

# %%
#--->Accessing Substrings from a String

# %%
# Concept of Indexing
c = "Hello"
print(c)
# Out:
# Hello

# %%
print(c[0])
# Out:
# H

# %%
print(c[4])
# Out:
# o

# %%
print(c[5])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 print(c[5])
#
# IndexError: string index out of range

# %%
#Types of Indexing
# Postive Indexing
#Negative Indexing
print(c[-1])
# Out:
# o

# %%
print(c[-5])
# Out:
# H

# %%
 # Slicing
c = "Hello World"
print(c[0:5])
# Out:
# Hello

# %%
print(c[2:])
# Out:
# llo World

# %%
print(c[:4])
# Out:
# Hell

# %%
print(c[2:6:2])
# Out:
# lo

# %%
print(c[0:6:-1])

# %%
print(c[-5:-1:2])
# Out:
# Wr

# %%
print(c[::-1])
# Out:
# dlroW olleH

# %%
print(c[-1:-5:-1])
# Out:
# dlro

# %%
#Editing and Deleting in Strings

# %%
c = "Hello"
print(c)
# Out:
# Hello

# %%
c[0] = 'X'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 c[0] = 'X'
#
# TypeError: 'str' object does not support item assignment

# %%
#This error said no python editing
# Strings are a Immutable Data Type

# %%
c ="world"
print(c)
# Out:
# world

# %%
print(c)
# Out:
# world

# %%
c[5] = "X"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 c[5] = "X"
#
# TypeError: 'str' object does not support item assignment

# %%
#Deletion
c
# Out:
# 'world'

# %%
print(c)
# Out:
# world

# %%
del c
print(c)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 2
#       1 del c
# ----> 2 print(c)
#
# NameError: name 'c' is not defined

# %%
c = "Hello"
del c[0]
print(c)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 2
#       1 c = "Hello"
# ----> 2 del c[0]
#       3 print(c)
#
# TypeError: 'str' object doesn't support item deletion

# %%
del c[:3:2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 del c[:3:2]
#
# TypeError: 'str' object does not support item deletion

# %%
#String mai editing not allowed
#no part wise deletion

# %%
#---->Operations on Strings

#--->Arithmetic Operations
#--->Relational Operations
#--->Logical Operations
#----> Loops on Strings
#---->Membership Operations

# %%
#--->Arithmetic Operations
"Satyam" +" " + "Pandey"
# Out:
# 'Satyam Pandey'

# %%
print("*" * 50)
# Out:
# **************************************************

# %%
#--->Relational Operations

"Hello" == "World"
# Out:
# False

# %%
"Hello"!="World"
# Out:
# True

# %%
"Mumbai" > "Pune"
# Lexiographically
# Out:
# False

# %%
"Goa" < "Kolkata"
# Out:
# True

# %%
"kol" <"KOL"
# Out:
# False

# %%
#--->Logical Operations

"Hello" and "world"
# Out:
# 'world'

# %%
#""-->False
#"wreghr"->True

# %%
"" and "Hello"
# Out:
# ''

# %%
"hello" or "world"
# Out:
# 'hello'

# %%
 not "hello"
# Out:
# False

# %%
 not ""
# Out:
# True

# %%
#----> Loops on Strings
c = "Hello World"
for i in c:
    print(i)
# Out:
# H
# e
# l
# l
# o
#
# W
# o
# r
# l
# d

# %%
#---->Membership Operations

'h' in c
# Out:
# False

# %%
'H' in c
# Out:
# True

# %%
'world' not in c
# Out:
# True
