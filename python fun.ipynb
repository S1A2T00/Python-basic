# %%
print("Hello World")
# Out:
# Hello World

# %%
print(6)
# Out:
# 6

# %%
print(False)
# Out:
# False

# %%
print("India", "Pakistan", "Nepal")
# Out:
# IndiaPakistanNepal

# %%
print("India", "Pakistan", "Nepal")
# Out:
# India Pakistan Nepal

# %%
print("India", "Pakistan", "Nepal",sep='-')
# Out:
# India-Pakistan-Nepal

# %%
print("India", "Pakistan", "Nepal",sep='/')
# Out:
# India/Pakistan/Nepal

# %%
print("Hello")
print("World")
# Out:
# Hello
# World

# %%
print("Hello",end=' ')
print("World")
# Out:
# Hello World
