# %%
#Common Functions
#len
#max
#min
#sorted

# %%
c = "kolkata"
len(c)
# Out:
# 7

# %%
max(c)
# Out:
# 't'

# %%
min(c)
# Out:
# 'a'

# %%
sorted(c)
# Out:
# ['a', 'a', 'k', 'k', 'l', 'o', 't']

# %%
sorted(c,reverse=True)
# Out:
# ['t', 'o', 'l', 'k', 'k', 'a', 'a']

# %%
# 1. Capitalize/Title/Upper/Lower/Swapcase

# %%
c
c.capitalize()
# Out:
# 'Kolkata'

# %%
"satyam".capitalize()
# Out:
# 'Satyam'

# %%
"satyam pandey".title()
# Out:
# 'Satyam Pandey'

# %%
c.upper()
# Out:
# 'KOLKATA'

# %%
c.lower()
# Out:
# 'kolkata'

# %%
"KolkAtA".swapcase()
# Out:
# 'kOLKaTa'

# %%
# Count
"it is raning".count("i")
# Out:
# 3

# %%
#find /Index
"it is raning".find("g")
# Out:
# 11

# %%
"it is raining".index("rain")
# Out:
# 6

# %%
#-->endswith/startswith

# %%
"it is raining".endswith("ingef")
# Out:
# False

# %%
"it is raining".startswith("it")
# Out:
# True

# %%
# Format
"Hello my name is {} and I am {}".format("Satyam",23)
# Out:
# 'Hello my name is Satyam and I am 23'

# %%
"Hello my name is {1} and I am {0}".format("Satyam",23)
# Out:
# 'Hello my name is 23 and I am Satyam'

# %%
"Hello my name is {name} and I am {age}".format(name="Satyam",age=23)
# Out:
# 'Hello my name is Satyam and I am 23'

# %%
#isalnum/isalpha/isdecimal/isdigit/isidentifier

# %%
"FLAT20".isalnum()
# Out:
# True

# %%
"FLAT20".isalpha()
# Out:
# False

# %%
"20A".isdigit()
# Out:
# False

# %%
"hello world".isidentifier()
# Out:
# False

# %%
"hell_world".isidentifier()
# Out:
# True

# %%
#Spilt
"Who is the pm of india".split()
# Out:
# ['Who', 'is', 'the', 'pm', 'of', 'india']

# %%
"Who is the pm of india".split("pm")
# Out:
# ['Who is the ', ' of india']

# %%
"Who is the pm of india".split("x")
# Out:
# ['Who is the pm of india']

# %%
#Join
" ".join(['Who', 'is', 'the', 'pm', 'of', 'india'])
# Out:
# 'Who is the pm of india'

# %%
#Replace
"Hi my name is Satyam".replace("Satyam","Sanjay")
# Out:
# 'Hi my name is Sanjay'

# %%
#Strip
name = "              Satyam       "
name.strip()
# Out:
# 'Satyam'
