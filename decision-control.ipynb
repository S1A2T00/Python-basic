# %%
# naam=Satyam 
#Password=1234
naam=input("Apna naam bata")
password=input("Apna password bata")
if naam=="Satyam" and password=="1234":
    print("Hello")
else:
    print("Incorrect")
# Out:
# Apna naam bata Poonam
# Apna password bata 4567
# Incorrect

# %%
naam=input("Apna naam bata")
password=input("Apna password bata")
if naam=="Satyam" and password=="1234":
    print("Hello")
elif naam == "Satyam" and password !="1234":
    print("Password incorect")
    password=input("Password fir se bolo")
    if password == "1234":
        print("Finally correct")
    else:
        print("Still Incorrect")
else:
    print("Incorrect")
# Out:
# Apna naam bata Satyam
# Apna password bata 1234
# Hello
