# %%
sample="how are you ?"
print(sample.split())
L=[]
for i in sample.split():
    print(i.capitalize())
    L.append(i.capitalize())
print(L)
print(" ".join(L))
# Out:
# ['how', 'are', 'you', '?']
# How
# Are
# You
# ?
# ['How', 'Are', 'You', '?']
# How Are You ?

# %%
sam="cde@gmail.com"
print(sam[:sam.find("@")])
# Out:
# cde

# %%
L1=[1,1,2,2,3,3.4,4]
L2=[1,2,3,1]
L=[]
for i in L2:
    if i not in L:
        L.append(i)
print(L)
# Out:
# [1, 2, 3]
